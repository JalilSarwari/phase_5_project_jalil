# %%
import numpy as np
import pandas as pd
from copy import deepcopy
import json
#visualization packages
import seaborn as sns
import matplotlib.pyplot as plt

# NLP modules we will use for text normalization
import re #regex 
import nltk # the natural language toolkit
from nltk.tokenize import word_tokenize
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk import pos_tag

# feature construction
from sklearn.feature_extraction.text import TfidfVectorizer #use this to create BoW matrix
import pyLDAvis.sklearn # a specialized package for topic model visualization

#modeling and dimensionality reduction for visuaization
from sklearn.decomposition import NMF
from sklearn.manifold import TSNE
# Out:
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/decomposition/_lda.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# additional argument sets cut off minimum length for tokenized text at which function converts to null string.
def process_tweet(tweet_text, min_length):
    
    # get common stop words that we'll remove during tokenization/text normalization
    stop_words = stopwords.words('english')
    new_words = ['u','ur',',','https',"'","i'm",'like','lol','get','one','http',
                "reeee","bro","need","tbh","ppl","wow","dude","ye","okay","ik","ep",
                 "ya","plz","need","look","idk","c",'b','imo','smh','haha',"n't",
                '.first','wtf','ta','im',"’"]
    stop_words = stop_words + (new_words)
    #initialize lemmatizer
    wnl = WordNetLemmatizer()

    # helper function to change nltk's part of speech tagging to a wordnet format.
    def pos_tagger(nltk_tag):
        if nltk_tag.startswith('J'):
            return wordnet.ADJ
        elif nltk_tag.startswith('V'):
            return wordnet.VERB
        elif nltk_tag.startswith('N'):
            return wordnet.NOUN
        elif nltk_tag.startswith('R'):
            return wordnet.ADV
        else:         
            return None
   

    # lower case everything
    tweet_lower = tweet_text.lower()

    #remove mentions, hashtags, and urls, strip whitspace and breaks
    tweet_lower = re.sub(r"@[a-z0-9_]+|#[a-z0-9_]+|http\S+", "", tweet_lower).strip().replace("\r", "").replace("\n", "").replace("\t", "")
    
    
    # remove stop words and punctuations 
    tweet_norm = [x for x in word_tokenize(tweet_lower) if ((x.isalpha()) & (x not in stop_words)) ]

    #  POS detection on the result will be important in telling Wordnet's lemmatizer how to lemmatize
    
    # creates list of tuples with tokens and POS tags in wordnet format
    wordnet_tagged = list(map(lambda x: (x[0], pos_tagger(x[1])), pos_tag(tweet_norm))) 

    # now we are going to have a cutoff here. any tokenized cocument with length < min length will be removed from corpus
    if len(wordnet_tagged) <= min_length:
        return ''
    else:
         # rejoins lemmatized sentence 
        tweet_norm = " ".join([wnl.lemmatize(x[0], x[1]) for x in wordnet_tagged if x[1] is not None])
        return tweet_norm

# %%
# Opening JSON file
filepath = 'messages_with_replies.json'
f = open(filepath)

# returns JSON object as 
# a dictionary
data = json.load(f)
f.close()

# %%
data.values[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 data.values[0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
message
# Out:
# ['OOF, poorly scheduled messages',
#  'https://t.me/c/1179447288/67840',
#  'As an iPhone user this cannot stand',
#  'AMC has a vip line for snacks',
#  'Omrahn do it for the memes',
#  'No he’s not',
#  'He’s practically your idol at this point',
#  'Do it',
#  'John time to brainstorm',
#  'I feel we would have to get something no one ever got before to do that',
#  'U guys should try to get on the tik tok',
#  'I’m down',
#  'Ockywaysuresure.gif',
#  "Don't ignore me Omrahn",
#  "And anyone else who's interested :)",
#  'I will, no joke, plan a day trip with u next month to go to the ocky store if ur willing',
#  'Omrahn',
#  'Holy fuck, jamshid and hassib heavy as fuck',
#  'Simple joke, simple meme',
#  'Omrahn brings 3 friends to play fifa',
#  'Holy shit',
#  'Why am I confused',
#  'There was no joke',
#  'I just thought it was funny',
#  'Then what was the point of sending that',
#  'Ur not banned from fifa u weirdo',
#  'I just thought it was funny',
#  'There is no hypocrisy there u crazy man',
#  'I wanna see the full hypocrisy',
#  'Wait send the uncensored version',
#  'Play without me',
#  'You think I give a fuck',
#  'Matt @biggiethumbs',
#  'Vishal is playing D&D',
#  'Isn’t tonight overwatch night?',
#  'I’m free',
#  'Left as in left for the day',
#  '"Left" as in quit?',
#  'Bitch',
#  "I'm free fatty",
#  '@biggiethumbs',
#  '@biggiethumbs',
#  '@biggiethumbs',
#  'Hey @biggiethumbs fifa tn?',
#  'Manager left, I’m off tomorrow, not doing shit else for the rest of the day',
#  'Ey yo',
#  "Smh, THE WHEEL SPOKE AND YA'LL BROKE THE WHEEL",
#  'But dont worry, we are all going to be watching!',
#  'We start in 10 min, but we wont be in telegram voice chat or anything like that',
#  'Amelie!',
#  'Gw what?',
#  'Gw with us tonight',
#  'I watched chainsaw man, add me plz',
#  'Get jamshid to watch anime, I like it',
#  'Wow, genius plan',
#  'Holy shit',
#  'The animation is insane',
#  'Yeah lol it totally is',
#  'Is jamshid actually watching chainsaw man?',
#  'That seems harsh',
#  'Then maybe',
#  'Without any input on planning',
#  'If you consistently make the next 3 sessions',
#  'Maybe not',
#  'Maybe',
#  'You mean the main chat?',
#  'Can I be added to the 2nd chainsaw man chat uwu after',
#  'No imma do that now',
#  'John did u watch chainsaw man',
#  "Also I only fwd like thrice a day, ya'll so dramatic!",
#  'Others have just put such eloquent messages in the past. As my favorite genius would say, good artists copy, great artists steal',
#  'I’m so mad I can’t think of anything to top this',
#  'HE SAID U AINT GOT NO NIPPLESSSSSSSSSSSSS',
#  'As an expert in forwarding messages you gots to chill',
#  'He beat me by one sec',
#  'i love being a dick about peoples boundaries',
#  'Please dont spam the chat. Personal boundary',
#  'Personal boundaries thanks!',
#  'Rap chat thanks',
#  'Father Time best song',
#  'Kendricks album got me like',
#  'Coward smh',
#  'YOU CANT ESCAPE THE CESSPOOL',
#  'Jamshids not here, how does he know 🤔',
#  'Just finished watching op',
#  'mattee wyd bro',
#  'Yo remember the scene where the guy was like, "well shucks, I guess we better call saul!" sooo crazy',
#  'Brendan laughing',
#  'Hi',
#  'Something',
#  'Matt',
#  'Tik tok will be a thing on the side',
#  'Im just here so i can become a pt',
#  'Ik more than my coach in terms of actual performance',
#  'Ye thats why im in college',
#  'Otherwise its a waste of time imo',
#  "Idk the #'s but theres a certain threshold u need to make serious $",
#  "I'd rather be a parasitic rich tik toker than a well paid engineer lmaoooo",
#  'I would personally do both at the same time',
#  'How bout u focus on getting a stable job/income instead of being a parasitic Tiktok influencer',
#  "I think it's better to get a fan base by being entertaining, then get cancelled and have a redemption arc",
#  'Profit',
#  'From there we can tree branch their interest into other things',
#  'But increase interest',
#  'True',
#  'Not trye',
#  'It turns heads',
#  'Like make up some shit so crazy',
#  'No i mean',
#  'Talk about ur body struggles, make it a bit toxic and inspirational, bada bang bada boom, profit',
#  'I then wanted to find a way to correlate that to my fields of interest',
#  'I was thinking ab how a persona like andrew tate can speak topics into relevance',
#  'Last time we talked about money was for an airbnb',
#  'Not with anyone here lma9oooo',
#  'Thats y mods do it',
#  'Public consensus and propaganda',
#  'Y’all don’t just talk ab money?',
#  '…',
#  'Mattee if your business plan involves monetizing reddit',
#  'my dick',
#  'What are some huge things that grew from social media',
#  'Hold on',
#  'Alright',
#  'Interesting',
#  'astro turfing or w.e by big companies',
#  'i would say there could be a higher motive',
#  'No lol',
#  '…',
#  '?',
#  'So no',
#  'Is this your first time on r/wallstreetbets reddit?',
#  'So no way to profit?',
#  'A lot of people live on the internet',
#  'Yk',
#  'I wouldn’t do this for free unless we having a convo',
#  'Wym updates',
#  'Like it’s a job',
#  'All this shit blah blah',
#  'Na i mean like they posting updates',
#  'False',
#  'Reddit will do nothing for you',
#  'Can u profit from reddit?',
#  'it all makes sense',
#  'Big if true',
#  'No, fuck is faster than mattee',
#  'Oh im faster now',
#  'I don’t like no cap og fr mattee',
#  'I miss I’m fast as fuck mattee',
#  'Define weird my friend',
#  'Point proven',
#  'Ya….',
#  "You're what",
#  'Not my fault you’ree',
#  'Y’all was hating on me',
#  'Y’all started the other shit',
#  'This was just funny uwu girl or wtv',
#  'We make a coppin baddies GC',
#  'I propose',
#  'No cap',
#  'Fr',
#  'Ong',
#  '💯',
#  'They gone hate you whenever',
#  '🗣️',
#  'They hate u when u up',
#  'B4',
#  'But where was this at',
#  'U call it flexin',
#  'Cringe',
#  'You like mattee trying to flex on us with shit we already did',
#  'Do you really',
#  'Do you John',
#  "I personally enjoy hearing about Mattee's adventures in college, I just wish it was less cryptic",
#  'Very well said',
#  'Huh',
#  'Nah it’s just Mattee’s being weird\nLike keep that stuff with your friends\nI’m happy he’s having fun in college but he doesn’t need to document it to us to “flex”',
#  'He hates this chat',
#  'Wow jamshid really hates fishing huh',
#  'Im fishing with the boys rn',
#  "Idt it's cringe to be in college",
#  'It’s cringe',
#  'Yeah but like none of us are in college except for him',
#  "That's what college is for",
#  'Mattee has been very cringe lately',
#  'Yeah I’m with jalil',
#  'Cringe',
#  'Look what you did',
#  'Thank you brendan',
#  'And forgot to search for it',
#  'name a more dead chat challenge [IMPOSSIBLE]',
#  'I haven’t herd this in so long',
#  'We make a coppin baddies GC',
#  'I propose',
#  'Or tmr',
#  'We may watch the demon slayer movie later',
#  'We still snappin hold on',
#  'LMAOOO',
#  'Ohhhh',
#  'Results?',
#  'WHAT THE FUU-BOOOOOMMMMMMM',
#  'Fuck u Matt',
#  'John when the sashimi hits the table',
#  'My b',
#  'John ordering his 50th piece of sashimi',
#  "It's u_u girl",
#  '😂😂',
#  'Ya boy’s been a dirty slut can’t lie',
#  'I only told u guys bc its an uwu girl',
#  'WHOOOOOAA',
#  'How about you Rev me up like Pochita and then I can be the devil inside you ( ͡👁️\u202f͜ʖ ͡👁️)',
#  'I will give you $50',
#  'mattee bro send her the google doc',
#  'Hello 0_0 my watchlist is chainsaw man 1_1 and vinland saga >_< how bout u OwO',
#  '@_@',
#  'u_u',
#  'Got his priorities in line',
#  'I’m kinda flattered mattee is finally gonna get some and his first reaction was “I can’t wait to tell the boys”',
#  '@FoundingChad punching the air rn',
#  'Yk what im sayin',
#  'Bouta cop one reaaalllll quick',
#  'Did this bitch just say u_u',
#  'Me seeing a debate in the master chat',
#  'RIP',
#  'You’re a dead man hagrid!',
#  'RIP',
#  'Ye',
#  'Ah i c',
#  'Monke place shield that stops explody bitch from exploding bitch 2',
#  'What am I looking at here',
#  'Then you didn’t do it',
#  'I’ve done this but forgot to clip it',
#  'Was he short skinny with a high pitched voice',
#  'It might’ve been',
#  'Was this that heat transfer professor I went to that one time when I was there?',
#  'O i c',
#  'There was a 4 month gap they could have easily found something',
#  'Im surprised they took him out without any investigation',
#  'But there isnt any actual evidence of a relationship',
#  'Wow',
#  'Head of the department',
#  'A professors response',
#  'Original reddit post',
#  'Send the actual link',
#  'Yoooo professor at UB might have been fucking a student and has been removed from teaching',
#  'Nice',
#  'I can’t be racist I use dark mode',
#  'The knowledge of a true racist',
#  '5K or cross country',
#  'What race would u make him',
#  'Ah yes the Jamaican grim reaper',
#  'Wtf is warner bros doing',
#  'End of an Era lads',
#  'no',
#  'Yo fifa tn boys',
#  'YOU FUCKING IDIOT',
#  'Look i said that here',
#  'Yeah im off tmr',
#  'Lmaooo',
#  'https://t.me/c/1179447288/87623',
#  'Yessir',
#  'I woke up, everything went downhill after',
#  'Off tomorrow?',
#  "Today's my last day of the week :)",
#  'Someone woke up on the wrong side of the bed this morning',
#  'What’s so good about it',
#  'Is it',
#  'Gm',
#  'Good morning',
#  'And apple mid',
#  'Well I wanted to read',
#  'https://twitter.com/Forbes/status/1580299530205302784',
#  'Dude thinks I typed this up like some Fibbage prompt lmao',
#  "I was expecting more good music from him, shame he's so far gone",
#  'Woah, contradicting respects going on here...',
#  'Send the actual link',
#  'Thanks omrahn',
#  '“The same jutsu won’t work on me twice”',
#  '“ i too”',
#  'He did say',
#  'I mean not really',
#  'Very ironic',
#  'New meta dropped',
#  'Based',
#  'I too love trivializing and mocking peoples complaints',
#  'Oh god a screenshot everyone run for cover',
#  'Bitch',
#  'u tried to throw me under the bus',
#  "So to wrap this conversation up,\nI don't deserve to be respected and this is a non issue and I hate no right to be upset.\ngot it 👍",
#  'Solution:',
#  'A solution looking for a problem',
#  'Respect must be earned',
#  "What's the solution, Idk",
#  'Das crazy dawg',
#  "Everyone needs to respect each other but each other's respects start contradicting",
#  'lots of great points',
#  'Interesting',
#  'Fair? You want… fairness?',
#  'Hacking to the gate 😂',
#  "Can't wait to fwd this haha",
#  'We all do this tbf',
#  'JOHN STOP BRINGING REAL LIFE INTO THIS YOU ALWAYS DO THISIHATEYOUFUCKINGRETARD',
#  "Honestly everyone should just give me a # from one to 10 and that's how much respect I'll show them",
#  'U wish u were a line fatty',
#  'He’s not outta line he’s perfectly in line',
#  'Respectfully of course',
#  'Fuck you',
#  'I respect your paradoxical boundary',
#  'I too will advocate for excessive amounts of group chats and also ban everyone from adding me to groupchats',
#  'Will anyone respect that boundary? Of course not',
#  'One of which is I dislike too many groupchats',
#  'I also have boundaries',
#  'You love gargling balls so much im surprised your even able to produce sperm properly after witnessing the greatness of kanye',
#  'Bro jamshid is gonna be making more than all of us combined when it’s all said and done',
#  'Im saying',
#  'What the hell are you saying',
#  'Why not throw a little cte in there',
#  'U always sucking off jamshid for his money',
#  'Yes',
#  'You really want Kanye in your corner?',
#  'Mr west has 😎',
#  'Brockport? Neva heard of it 😎',
#  'mid input',
#  'You guys are all dumb',
#  'As a third party',
#  'This is a majority conservative group chat',
#  'Free dumbs',
#  "It's simple",
#  'Discourse',
#  'I’m just asking u guys not to do it idk why you’re so against it',
#  'Then why even send it? 🤔',
#  'Yeah we know',
#  'I too dont like admitting when im wrong',
#  'AHHHHH JALIL MIGHT PLAY OVERWATCH GOTEM FRAUD CRINGE OWNED',
#  'This wasn’t shit like that',
#  'He did leave the groupchat because of shit like that',
#  'I mean',
#  "Apparently sending a screenshot of a harmless yes/no question is bad. Y'all so dramatic",
#  'This is the store',
#  'Lie',
#  'He don’t got pork',
#  'He’s Muslim even the bacon is beef',
#  'But HE PUTS BACON ON THE GRILL',
#  "I honestly think he's gonna do that",
#  'Just no pork',
#  'IM down',
#  'Honestly I’m down to go with whoever wants to go',
#  'NOW WE PUT THE MOZZARELLA STICKS IN THE SALAD',
#  'We ask for a salad',
#  'We don’t get a bev',
#  'yo Ock lemme get a chop cheese mcdgriddle the ocky way',
#  'I think that’s been done tbh',
#  'Hey ock can I get a ramen and pop tart burger but NO SPINACH',
#  'We gotta get something original at the ocky store',
#  "I've been asking for MONTHS and now u wanna go",
#  'Are u fucking kidding me',
#  "Bruh, I stopped a while ago, don't bring me into this cuz u fucked up 🥰",
#  'How about you guys stop cause I asked, please',
#  'This wasn’t even a gotcha or an insult in any way lol',
#  'If u go through the media in the gc 90% of text screenshots are john',
#  'i love being a dick about peoples boundaries',
#  'i agree with you',
#  'no no',
#  'Ah yes exaggerate',
#  'I too love dictating what people deserve to be upset about',
#  'kinda yeah',
#  'is that a serious offer',
#  'You wanna go?',
#  'Omrahn',
#  'It’s so people who get banned for cheating can’t make a new account that easily',
#  'What a trivial thing to be upset about',
#  "I'm just saying, I haven't done it in forever",
#  "it's fucking annoying and i've said before i don't like when you guys do it",
#  "Y'all?!",
#  'Wooooooooooow',
#  'Y’all take screenshots of my messages left and fucking right',
#  'I do hate it',
#  "If this guys still in the game, I'm down",
#  'My overwatch experience',
#  '👍',
#  'I LOVE GETTING TO WORK WHILE THE FUCKING SUN ISNT UP',
#  'I FUCKING LOVE WAKING UP EARLY',
#  '“Brendan should have kept running” - jamshid',
#  'Oh thats where that meme came from',
#  'Give this man a tv show honestly',
#  '2nd half time',
#  'Only childs dont count',
#  '?',
#  'Eldest child gang',
#  'yeah talk yo shit',
#  'Everyone complains about dead groupchat and no activities until its time to actually commit to something smdh',
#  'but i take the wok to poland',
#  'mattee you might be that guy',
#  'Fr fr lmao on moms thats brazy',
#  'Goddamn that’s funny',
#  'greg demoted to defense if he does',
#  'Is Matt making an appearance?',
#  'I’ll be on at 830 tonight',
#  'No its cuz spongebob took the vax',
#  'Wasn’t the cure for this just taking a shower or something',
#  'Hope u feel better ♥',
#  'Sick of you bitches',
#  'What kinda sick',
#  'I blame the sarwaris',
#  'And 2nd week, already no event',
#  'We picked one day',
#  'Look at that',
#  'Oh wow hassib',
#  'Smh no fifa on a Tuesday',
#  'Is it dead or poppin',
#  'Another dead chat',
#  'Add me plz',
#  'Something something terrorist',
#  'Its poppin rn',
#  'Add me back',
#  'Oh shit',
#  'I will drive to Long Island and blow up your house',
#  'Please use the fifa chat ty',
#  'I see no reason why not',
#  'Well if Jalil and jamshid are back',
#  'I hope we have fifa',
#  'So is fifa happening tn?',
#  'Do you even limewire',
#  'Yes',
#  'U guys remember dial up?',
#  'Just watched the mario movie its pretty good',
#  'M’Award',
#  'Jesus christ',
#  'Unions municipalities local governments whatever',
#  '"Unions"',
#  'Is fifa Tuesday still a thing tomorrow?',
#  '"dealing with crap" = prophet',
#  'Tomorrows lottery numbers are 420 69 69',
#  'I must be a prophet',
#  'No I mean like even if you get the funding you’d have a nightmare dealing with unions and crap',
#  'We are truly our own worst enemy',
#  'Oof',
#  'Tik tok go crazy td',
#  'Date?',
#  'So did I \U0001f972',
#  'I thought ur going to a bills game in NYC what the FUCK',
#  'I can maybe do end of November',
#  'I’m going to be in Michigan so no',
#  'So I can plan my life',
#  "@biggiethumbs Brendan Greg Stimitz plz tell me that we're hanging out Nov 4th weekend",
#  'I need to know something now',
#  'Damn',
#  'They’ll reappear on Tuesday',
#  'Still can’t believe jamshid thought he was top 4',
#  'Goated anime',
#  'Ah a man of culture leaving that crap',
#  'Damn, add me back to the FIFA chat!',
#  '45? Im in 63. Ur missing out',
#  'Now this I can get behind',
#  'Matt should play fifa 23 instead of watching the notebook',
#  'Mid',
#  'We should just do this to Russia',
#  'We should stop supporting them and start worrying about ourselves',
#  'He he he',
#  'They’re lowkey giving Russia the works',
#  'They still goin?',
#  "Life ain't so bad",
#  'Ukraine should surrender',
#  'Quick someone say something controversial',
#  'Damn we have 45 group chats and they’re all dead',
#  'I am free tomorrow night believe it or not',
#  'Apple users on suicide watch',
#  'House of the dragon would never',
#  'Ep7 came out today',
#  'Wow',
#  'is it really that bad',
#  "why i can't",
#  'give me one good reason',
#  'We gotta say it somewhere',
#  'We can’t use words like faggot in that chat',
#  '😈😈😈',
#  'Why’d u stop typing',
#  '😈😈😈😈',
#  'Took a while jammy',
#  'I doubt you will surpass me',
#  'Jamshid count your days',
#  'New pr 245x3',
#  'Greg had to explain it to me lmao',
#  'LMFAO',
#  'cringe',
#  'Thanks zaddy',
#  'People seeing me walk in with bobby bitch blasting on repeat',
#  'WOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO',
#  'I’m on my couch actually',
#  'Lol',
#  'I see the cum wall u got',
#  'I see the sandwich on your chest',
#  'I see u on your bed',
#  'Yeah u',
#  'You look like u need some bitches',
#  'You almost look like your balls dropped',
#  'That mustache is so cute',
#  'I quite literally know more than u',
#  'I thought you had weights to lift',
#  'WOOOOOO',
#  'IM IN JIM',
#  'Check mate',
#  'Fifa gc and mechanical gc cant be the same',
#  '…',
#  'If i had more energy I would’ve continued this convo then argued',
#  'The main chat and the FIFA chat cant be the same thing',
#  'Im back',
#  'Yea.. That makes it So unsettling 😂',
#  'The loop makes it look like she’s jerking off',
#  'This is so unsettling',
#  'Go watch this movie, ty',
#  'Bye',
#  'I go pump iron',
#  'Jalil and jamshid both left telegram but we have to make new gcs because they spoiled asses think everything is about them and then will throw a fit when the topic is not there pleasing',
#  'There’s literally a skip messages button',
#  'How bout you shut the fuck up and let people talk',
#  'The main chat and the FIFA chat cant be the same thing',
#  'Its true tho',
#  'All that typing',
#  '🥰',
#  'This shit again',
#  'But yeah I don’t care enough to count messages',
#  'The way telegram exports makes it harder',
#  'Then again by color',
#  'Cause I was going to see if I could filter by messages sent by deleted account',
#  'For deleted accounts?',
#  'How do you need python to count x number of messages',
#  'Use Matlab',
#  'Cringe',
#  'I have all of them though',
#  'Won’t work unless I can learn python',
#  'Your conclusions?',
#  'No I was trying to count messages',
#  '^',
#  'What timeline',
#  '@biggiethumbs did u ever finish that timeline btw?',
#  'You called any episode of code geass with character building a filler',
#  'Yeah I love hearing someone rambling without moving their mouth',
#  'Monologues are the best',
#  'If I hear so much as one monologue I’m quitting',
#  'Hassib not allowed to watch',
#  'Wtf',
#  'I win bye bye',
#  'Cope',
#  'Ratio',
#  'L',
#  'Exposed',
#  'Nope',
#  'Anime just fucking sucks in general',
#  'I am intrigued',
#  'Manga is supposedly very hype',
#  '@FoundingChad',
#  'Idk how to @ a name',
#  'Android idiots smh',
#  'Is nothing sacred smh',
#  'fuck u John',
#  'From this chat',
#  'He fwded omrahn message!',
#  'What did John do now',
#  'Low blow john',
#  'Screw u John',
#  'Ofc the people who hate popular movies hate the Mario movie',
#  'An hour left of work and I’ve mentally checked out 3 hours ago',
#  'Comes out next week',
#  'Is this show good? I see it everywhere',
#  'Greg wow',
#  'Brendan there’s no thumbnail I’m not clicking that',
#  'This guy is shit',
#  'Some heat^',
#  'https://youtu.be/hFZFjoX2cGg',
#  'Great channel',
#  'Oh I’ve been watching fam',
#  'If you guys wanted that engineering guy i like to watch',
#  'https://www.youtube.com/c/PracticalEngineeringChannel',
#  'Got em',
#  "There's noticeable actors that we could've memed on too",
#  'Fuck you guys for not watching it last weekend',
#  'Great movie',
#  'I watched Smile',
#  'Maybe here',
#  'O',
#  'or at least rejoin',
#  'This is wrong',
#  'Oh i thought u meant came back',
#  'Are we making a fucking timeline?',
#  'Nah',
#  'This will never be addressed but it should!',
#  'June 11th',
#  "it's actually fun trying to figure this out",
#  'reasons',
#  'Wha',
#  'thank',
#  "You're welcome",
#  'June 11th',
#  'or at least rejoin',
#  'is important',
#  'halp',
#  '@everyone what date did jalil and jamshid delete telegram',
#  'What GC should we make now?',
#  'Yo Jamshid',
#  'Get some help',
#  'Stop it',
#  'wHaT Gc SHoUlD i MaKe nOw',
#  'Like u da be sittin in your corner thinking about',
#  'Im sorry your brain is so fried by medical knowledge the best your shower thoughts can be are fucking gc ideas',
#  'get his ass boi',
#  'Its the main chat',
#  'Mattee why even stay in this chat',
#  'This man doesn’t watch wild n out and it shows',
#  'Dirty ass nibba',
#  'You took a shower and lost weight',
#  'U look like future’s past',
#  'Alright future chill',
#  'U shlob on dis knob',
#  'Yo mama',
#  'Okay fine I’ll call him later',
#  'In what world',
#  'Plz Take this to the "eldest childs who\'s the bigger virgin battle" GC plz tyvm!',
#  'The delusion',
#  'Still can’t believe jamshid thought he was top 4',
#  'Jalil and Mattee would be swapped in an undeleted world obviously',
#  "If only omrahn wasn't at the airport",
#  'If only fifa was as successful at fortnite',
#  'The shot was deflected by an enemy player and rolled into the goal',
#  'I believe I scored the 2nd goal',
#  'It was the game we lost 2-5',
#  'Damn i gotta get back into the habit of sending clips',
#  'Which goal',
#  "I'd like to see it plz",
#  'I hope @biggiethumbs clipped that one :/',
#  'Oh 😂',
#  'You gotta leave a few seconds for the “OOOOO”',
#  "I'm not sure what u mean",
#  '?',
#  'John',
#  'fraud',
#  'Fake news',
#  "could've played fifa",
#  'You read the important part at least',
#  'Opens telegram',
#  'Wow 300 + messages!\nFifa must be going well!\nI can’t wait to read whats going on',
#  'Wow look at all those messages I skipped at the click of a button',
#  "It's not even close",
#  'Who uses exclamation points the most?',
#  'The better question is who reacts the most to messages',
#  "excuse me this isn't fifa related",
#  'Most messages:\nJohn\nHassib\nBrendan\nMattee\nJalil \nJamshid\nOmrahn',
#  'Mattee I need you',
#  'Chess?',
#  'Brendan',
#  'Appearing offline',
#  'Notorious for random “I need you to do this”',
#  'He was dropping my dad off',
#  "You couldn't have dropped him/her/it off 3 hours earlier Omrahn",
#  'My dude join the party',
#  "I'm on but Where's everyone else lmao",
#  'I never planned on 8',
#  'Jalil 🍎 finish yo chicken',
#  'I was editing my character',
#  'John where tf are you',
#  'No way are Greg and bren on by 8',
#  'John Brendan Jalil 🍎',
#  'We start at 8:10',
#  'Is Matt making an appearance?',
#  'John @biggiethumbs Omrahn Jalil Brendan Gregory',
#  'T minus 25 minutes',
#  'Who asked',
#  'I had a good August',
#  'Rest are trash',
#  'One good day',
#  'August is highkey mid',
#  '8 it is',
#  '8 is fine too',
#  'Works for me',
#  'No way am I on till 11',
#  'I’d rather 8-11',
#  'Yea',
#  'What say the white people',
#  'Works for me',
#  'How about 830 sharp for all',
#  '8 for us, 7:30 for greg and Brendan',
#  'No way are Greg and bren on by 8',
#  '8-11',
#  'Make a miss chat chat',
#  'I miss the fifa announcement chat',
#  'This man spitting facts',
#  'Hope everyone is having a nice day and excited for FIFA tn!',
#  'Na',
#  "It shouldn't be this hard :)",
#  'We never figured scheduling out huh',
#  'Today, 1 year ago',
#  'Due to scheduling issues the only day for squid games is tonight',
#  'You guys know what today is 👀',
#  'This has already been done',
#  'Is this your business plan',
#  'Overwatch 2 anyone??',
#  'Yo ima build a school',
#  'But as a old person',
#  'And we strengthen those mobile areas early on to live healthy not just as an athlete',
#  'When they’re mobile and shit',
#  'But start them off at a young ageb',
#  'Maybe lighten the load',
#  'This is what we need',
#  'I dont get it',
#  'Thought that was a dude',
#  'What is bitchs?',
#  'I dont get it',
#  'You looked at it so analytically instead of just using common sense',
#  'What do you think',
#  'You’re kidding right?',
#  'It’s also a wireless charger',
#  'Having Simpsons decorations in front if the ps5 is also weird',
#  'Agreed',
#  'Having an alarm clock underneath seems strange',
#  'Mid setup mid player',
#  'This is a beautiful video, the bois spending the last mins of the OW1 servers together',
#  'This gif is so perfect for how I feel at the end',
#  'Yeah I should be free',
#  'Tomorrow? Fifa tomorrow? On fifa Tuesday?',
#  "Who's free for fifa tmrw?",
#  'This shot is SICKKK',
#  'Mid',
#  'Is the nfl vr game on ps vr Jalil ?',
#  'Dbz amc’s were peak YouTube back in the day',
#  'Still cool',
#  "Nvm it's an amv",
#  'THEY REANIMATED NARUTO VS SASUKES FIRST FIGHT',
#  'He just looks like a normal guy',
#  'The roasting is insane',
#  '#leaveDreamalone',
#  '...mid',
#  'Poor guy',
#  'So... How about Dreams face ey?',
#  'So you’re the reason John is horny for anime uwu girls?',
#  'Everything is mid, never be excited for anything, only negativity!',
#  'I was excited for one thing',
#  "Rue relapsing returns but now she's in college and has no safeguards",
#  "It's gonna be terrible",
#  "The fact this isn't us rn is incredibly dissapointing",
#  'Make up is so powerful',
#  'John, just subscribe to her OF and call it a day',
#  'Jesus needs me',
#  'John you need Jesus',
#  'Jamshid mid',
#  'YES BRENDAN BE SALTY',
#  'Ur dick prob limp from that twitch girl',
#  'Jesus Christ get off my dick already',
#  'Jamshid swimming in that copium',
#  'Sorry u cant figure it out with an android',
#  'He actually looked it up lol',
#  'Her twitch is NotAestheticallyHannah you fucking faggot',
#  '^there it is',
#  'please send this to the "john\'s being a dick" gc tvym!',
#  'U faggot',
#  'She is uwu girl',
#  'Got it',
#  'Welp, now its clear ur just being a dick for whatever reason you have',
#  'Like use ur Apple Search App?',
#  'Maybe u can search?',
#  'Bro',
#  'John',
#  "Don't delete my shit",
#  'Cringe',
#  'Anyways, what’s that chicks name',
#  'Who knew making Omrahn admin was a mistake',
#  'All hail Greg Stimitz',
#  'Thank fucking God for this chat',
#  'Jam complains about messages then stares at his phone constantly',
#  'Yes',
#  'Man couldn’t scroll past 1 message without getting his panties in a twist',
#  'Please take this convo to "is there a GC for this?" GC Plz thank u',
#  'Aren’t u driving',
#  'Man shut YO BITCH ASS UP',
#  'He is a rapper',
#  'Theres a rap gc',
#  'There is 100% a music gc',
#  'thank GOD',
#  "his latest album sold 17k, it's over",
#  'If will smiths movie wasn’t enough to convince nothing will',
#  'Until more and more parents realize how stupid it is to let their kids play',
#  'Everybody always says nfl is done but nfl will remain top dog',
#  'LMAOOOOOOOO',
#  'John',
#  'Nfl > nba',
#  'Lol NBA > NFL is a hot ass take',
#  'John',
#  "It's hard to focus without pics",
#  'U missed it',
#  'You can only say this is your present mf',
#  'Where u at its 2 smh',
#  'Wrong chat',
#  'We can grill though',
#  'I mean.... It did rain already and is gonna rain again today',
#  'Wow',
#  'Wut',
#  'U 1v1',
#  'But to take pieces',
#  'Its chess',
#  'Its moving away',
#  'Maybe Hassib was right',
#  'Did it rain 🤔',
#  'Im ducking bored and awake',
#  'Idea: tier lists for group chats',
#  'Fps chess',
#  "My butthole is stuffed, I'm ready",
#  'This game is a fucking shit show',
#  'You are now invited to the Pokemon chat',
#  "That's actually insane",
#  'Nsfl',
#  'Click at your own risk',
#  'This is our FIFA chat now',
#  'Hassib had to have beeen high',
#  'God damn',
#  'So far away',
#  'We appreciate u making it for sushi friday',
#  'Concert != traveling',
#  'You went to a concert yesterday…',
#  "In retrospect, this is crazy to say considering I was in Korea a week ago and now I'm on LI",
#  'Love ur self',
#  'You think that’s grotesque',
#  'My sweet summer child',
#  'Plz do',
#  'Shall i share',
#  'I have something absolutely grotesque',
#  'A little more sus don’t you think?',
#  'John you’re thinking about that too much',
#  'Matt this dude sus',
#  'He’d be on time every time',
#  'The only solution is for one of us to suck johns dick',
#  'Me neither',
#  "I got one topic of roast for each of ya'll",
#  'We could',
#  'Maybe we should play jackbox tn since the roasting is on point',
#  'Lmfao',
#  'Wrong chat',
#  'Jamshid all the time',
#  'John for his once a year trip for the boys',
#  'John for his third concert in a week',
#  'Ngl it doesn’t even feel real',
#  "That's some dedication",
#  'Reddit carefully showing me the same shit over and over again',
#  'No',
#  'So john unifies separate substances as a catalyst to create a reaction',
#  'Catalysts technically unite other chemicals to create a reaction',
#  'https://t.me/c/1179447288/84366',
#  'Most of the time yes',
#  'I truly am the great uniter',
#  'They tend to agree on most things recently',
#  'You know how fucked up you have to be to make me jalil and jamshid agree on something',
#  'Objectively not funny',
#  'Try harder',
#  'Classic gif',
#  'Simple\nSearch "wam"',
#  'That poor kid lol',
#  'Howd u find that',
#  'Whats the 🤔 wecommended 😭 wamount of 😜 ded-da-dated wam 😂 i shud halv 🧐 on my servur 😳',
#  'Can I pway on the ps5 UwU',
#  '*electric skateboards',
#  'Inability to pass the ball',
#  'Inability to ride hoverboards',
#  'It was the wrong answer',
#  'Strabismus?',
#  'He can watch two fifa screens at once',
#  'It’s a feature not a bug',
#  'Lmao',
#  "What's wrong with them",
#  'and how does it feel to be wrong when it wasnt even your question',
#  'I said him',
#  'Strabismus',
#  'Yesssir',
#  'Only if he can name the defect',
#  'Brendan make fun of Jamshid’s eyes',
#  '^',
#  'Bro how have you never noticed',
#  'Show me plz',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '☕️',
#  'No',
#  'Change my mind ☕️',
#  'You’re a genetic defect',
#  'I CAN SAY FIRST HAND MILITARY MONEY IS OBSCENE',
#  'DIVERT MILITARY FUNDS TO PAY FOR PUBLIC HEALTH CARE',
#  'Its a genetic defect',
#  'POLITICAL ARGUMENT HERE WE GO',
#  'I mean nuanced when compared to beliefs generally ascribed to either party',
#  'Everyone is dumb and bad at video games except jamshid',
#  'Brendan the most nuanced thign about you is your foot stance',
#  'The only nuanced opinions are jamshids',
#  'You do not have nuanced opinions',
#  'https://t.me/c/1179447288/79499',
#  'That sounds like socialism with extra steps',
#  'DEMOCRATIC socialism',
#  'This sounds so unrepublican',
#  'SO EVERYBODY JUST FOLLOW ME',
#  'NOW THIS LOOK LIKE A JOB FOR ME',
#  'Docs shouldnt get paid less, everyone else should be paid more',
#  'The goat',
#  'It was slim shady',
#  'Right right he had gloves on',
#  'He does not deserve to have a Porsche for that',
#  'I could’ve done that',
#  'Ik but it was a funny typo',
#  'My dude I went to a dermatologist and all he did was pop a cyst on my head with a needle',
#  'The proper line is "I got 99 problems and they all bitches" - Kid Cudi SMH',
#  'You had a point',
#  'No no',
#  '*paid',
#  'Doctors need to get laid extra so they can make up all the income they lost from studying till they 35',
#  'I have no idea I don’t research my hot takes',
#  'Doctors get fucked',
#  'I vaguely remember writing an essay on doctors and athletes',
#  '"Give up on your dream. Send those nfl players straight to hell"',
#  'Aren’t they underpaid',
#  'Doctors',
#  'You know who else is overpaid?',
#  'You know all this talk of athletes being overpaid',
#  'Here’s your big bag of money',
#  'Just walk it off pal, you have 36 more hits for this game',
#  'Dudes ripping a mad guitar solo, all clear',
#  'lmao',
#  'Fuck u uys',
#  '“Quick check his fingers”',
#  'Its on purpose',
#  'Ik',
#  'Mf you still haven’t told us your plan 😂😂',
#  'Actually sounds cool asf',
#  'Interesting',
#  'You don’t know how vague this is 😈',
#  'Neuroscience concussion inspector for NFL',
#  'HiS BuSinEsS pLAn',
#  '😂😂😂',
#  'Sends gif*',
#  'I just want to see what u guys think',
#  'What do u think im going to do after graduation',
#  'Oof',
#  'THE RECKONING WILL BE SWEET',
#  'I can’t till mattee graduates and doesn’t make anywhere near what we do lol',
#  'Thanks man',
#  'SHE ALL 99 OF THEM',
#  'I GOT 99 PROBLEMS AND A BITCH AINT ONE',
#  'We let the little boy dream',
#  'We know Omrahn, we know',
#  'I hope Jamshid becomes a professional youtube boxer like Dr. Mike one day',
#  'Mattee will never understand, he’ll never be one',
#  'Doctors like to keep things organized',
#  'OOF',
#  'Cuz unlike someone, i dont have a life',
#  'Well yes',
#  'Jamshid after wasting his life on a degree just to get mad at group chats',
#  'I jk but dont say anything',
#  'Cope',
#  'This man is a fraud',
#  'Yes',
#  'After i turn u 😈',
#  '🤔',
#  'U gone want some dick',
#  'Gotta question my choices?',
#  'THIS MANS IN CLASS LMAOOOO',
#  'Wasted college on books?',
#  'Why u on my dick bro',
#  'This man texting 8 guys at once',
#  'In class',
#  'You should be with your girls then',
#  ':)',
#  'Built different',
#  'U get mad books',
#  'I get mad girls',
#  'Yee',
#  'Shouldn’t you be going to college parties or something?',
#  'If u cant make that connection then maybe its time u put the booms down and go outside dr :)',
#  'Even if we sent studies jamshid wouldn’t read them',
#  'So',
#  'I cant add u to chats',
#  'Jamshid',
#  'Maybe it would be if you kept nfl stuff in there',
#  'How would you know? Wheres your PhD? Exam scores? Publications?',
#  'The nfl chat is not even that active',
#  ':)',
#  'Please leave your insecurities',
#  'Who are you?',
#  'Im talking to them',
#  'Brendan and hassib are responding',
#  '🥱',
#  'then stop fucking texting it in here',
#  'If he doesnt want to participate in it',
#  'There is literally an NFL chat',
#  'Please... get a hotel',
#  'Shit is fucked',
#  ...]

# %%
messagess = pd.DataFrame(message,columns = ['text'])
messagess
# Out:
#                                       text
# 0           OOF, poorly scheduled messages
# 1          https://t.me/c/1179447288/67840
# 2      As an iPhone user this cannot stand
# 3            AMC has a vip line for snacks
# 4               Omrahn do it for the memes
# ...                                    ...
# 51557      Jamshid watching that last game
# 51558               i missed the last game
# 51559                       That last game
# 51560                         Did it work?
# 51561           John - “The socks are off”
#
# [51562 rows x 1 columns]

# %%
messages['text'] = messagess['text'].apply(process_tweet, args = [9])

# %%
messages['text']
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 51557
# 51558
# 51559
# 51560
# 51561
# Name: text, Length: 51562, dtype: object

# %%
message
# Out:
# ['OOF, poorly scheduled messages',
#  'https://t.me/c/1179447288/67840',
#  'As an iPhone user this cannot stand',
#  'AMC has a vip line for snacks',
#  'Omrahn do it for the memes',
#  'No he’s not',
#  'He’s practically your idol at this point',
#  'Do it',
#  'John time to brainstorm',
#  'I feel we would have to get something no one ever got before to do that',
#  'U guys should try to get on the tik tok',
#  'I’m down',
#  'Ockywaysuresure.gif',
#  "Don't ignore me Omrahn",
#  "And anyone else who's interested :)",
#  'I will, no joke, plan a day trip with u next month to go to the ocky store if ur willing',
#  'Omrahn',
#  'Holy fuck, jamshid and hassib heavy as fuck',
#  'Simple joke, simple meme',
#  'Omrahn brings 3 friends to play fifa',
#  'Holy shit',
#  'Why am I confused',
#  'There was no joke',
#  'I just thought it was funny',
#  'Then what was the point of sending that',
#  'Ur not banned from fifa u weirdo',
#  'I just thought it was funny',
#  'There is no hypocrisy there u crazy man',
#  'I wanna see the full hypocrisy',
#  'Wait send the uncensored version',
#  'Play without me',
#  'You think I give a fuck',
#  'Matt @biggiethumbs',
#  'Vishal is playing D&D',
#  'Isn’t tonight overwatch night?',
#  'I’m free',
#  'Left as in left for the day',
#  '"Left" as in quit?',
#  'Bitch',
#  "I'm free fatty",
#  '@biggiethumbs',
#  '@biggiethumbs',
#  '@biggiethumbs',
#  'Hey @biggiethumbs fifa tn?',
#  'Manager left, I’m off tomorrow, not doing shit else for the rest of the day',
#  'Ey yo',
#  "Smh, THE WHEEL SPOKE AND YA'LL BROKE THE WHEEL",
#  'But dont worry, we are all going to be watching!',
#  'We start in 10 min, but we wont be in telegram voice chat or anything like that',
#  'Amelie!',
#  'Gw what?',
#  'Gw with us tonight',
#  'I watched chainsaw man, add me plz',
#  'Get jamshid to watch anime, I like it',
#  'Wow, genius plan',
#  'Holy shit',
#  'The animation is insane',
#  'Yeah lol it totally is',
#  'Is jamshid actually watching chainsaw man?',
#  'That seems harsh',
#  'Then maybe',
#  'Without any input on planning',
#  'If you consistently make the next 3 sessions',
#  'Maybe not',
#  'Maybe',
#  'You mean the main chat?',
#  'Can I be added to the 2nd chainsaw man chat uwu after',
#  'No imma do that now',
#  'John did u watch chainsaw man',
#  "Also I only fwd like thrice a day, ya'll so dramatic!",
#  'Others have just put such eloquent messages in the past. As my favorite genius would say, good artists copy, great artists steal',
#  'I’m so mad I can’t think of anything to top this',
#  'HE SAID U AINT GOT NO NIPPLESSSSSSSSSSSSS',
#  'As an expert in forwarding messages you gots to chill',
#  'He beat me by one sec',
#  'i love being a dick about peoples boundaries',
#  'Please dont spam the chat. Personal boundary',
#  'Personal boundaries thanks!',
#  'Rap chat thanks',
#  'Father Time best song',
#  'Kendricks album got me like',
#  'Coward smh',
#  'YOU CANT ESCAPE THE CESSPOOL',
#  'Jamshids not here, how does he know 🤔',
#  'Just finished watching op',
#  'mattee wyd bro',
#  'Yo remember the scene where the guy was like, "well shucks, I guess we better call saul!" sooo crazy',
#  'Brendan laughing',
#  'Hi',
#  'Something',
#  'Matt',
#  'Tik tok will be a thing on the side',
#  'Im just here so i can become a pt',
#  'Ik more than my coach in terms of actual performance',
#  'Ye thats why im in college',
#  'Otherwise its a waste of time imo',
#  "Idk the #'s but theres a certain threshold u need to make serious $",
#  "I'd rather be a parasitic rich tik toker than a well paid engineer lmaoooo",
#  'I would personally do both at the same time',
#  'How bout u focus on getting a stable job/income instead of being a parasitic Tiktok influencer',
#  "I think it's better to get a fan base by being entertaining, then get cancelled and have a redemption arc",
#  'Profit',
#  'From there we can tree branch their interest into other things',
#  'But increase interest',
#  'True',
#  'Not trye',
#  'It turns heads',
#  'Like make up some shit so crazy',
#  'No i mean',
#  'Talk about ur body struggles, make it a bit toxic and inspirational, bada bang bada boom, profit',
#  'I then wanted to find a way to correlate that to my fields of interest',
#  'I was thinking ab how a persona like andrew tate can speak topics into relevance',
#  'Last time we talked about money was for an airbnb',
#  'Not with anyone here lma9oooo',
#  'Thats y mods do it',
#  'Public consensus and propaganda',
#  'Y’all don’t just talk ab money?',
#  '…',
#  'Mattee if your business plan involves monetizing reddit',
#  'my dick',
#  'What are some huge things that grew from social media',
#  'Hold on',
#  'Alright',
#  'Interesting',
#  'astro turfing or w.e by big companies',
#  'i would say there could be a higher motive',
#  'No lol',
#  '…',
#  '?',
#  'So no',
#  'Is this your first time on r/wallstreetbets reddit?',
#  'So no way to profit?',
#  'A lot of people live on the internet',
#  'Yk',
#  'I wouldn’t do this for free unless we having a convo',
#  'Wym updates',
#  'Like it’s a job',
#  'All this shit blah blah',
#  'Na i mean like they posting updates',
#  'False',
#  'Reddit will do nothing for you',
#  'Can u profit from reddit?',
#  'it all makes sense',
#  'Big if true',
#  'No, fuck is faster than mattee',
#  'Oh im faster now',
#  'I don’t like no cap og fr mattee',
#  'I miss I’m fast as fuck mattee',
#  'Define weird my friend',
#  'Point proven',
#  'Ya….',
#  "You're what",
#  'Not my fault you’ree',
#  'Y’all was hating on me',
#  'Y’all started the other shit',
#  'This was just funny uwu girl or wtv',
#  'We make a coppin baddies GC',
#  'I propose',
#  'No cap',
#  'Fr',
#  'Ong',
#  '💯',
#  'They gone hate you whenever',
#  '🗣️',
#  'They hate u when u up',
#  'B4',
#  'But where was this at',
#  'U call it flexin',
#  'Cringe',
#  'You like mattee trying to flex on us with shit we already did',
#  'Do you really',
#  'Do you John',
#  "I personally enjoy hearing about Mattee's adventures in college, I just wish it was less cryptic",
#  'Very well said',
#  'Huh',
#  'Nah it’s just Mattee’s being weird\nLike keep that stuff with your friends\nI’m happy he’s having fun in college but he doesn’t need to document it to us to “flex”',
#  'He hates this chat',
#  'Wow jamshid really hates fishing huh',
#  'Im fishing with the boys rn',
#  "Idt it's cringe to be in college",
#  'It’s cringe',
#  'Yeah but like none of us are in college except for him',
#  "That's what college is for",
#  'Mattee has been very cringe lately',
#  'Yeah I’m with jalil',
#  'Cringe',
#  'Look what you did',
#  'Thank you brendan',
#  'And forgot to search for it',
#  'name a more dead chat challenge [IMPOSSIBLE]',
#  'I haven’t herd this in so long',
#  'We make a coppin baddies GC',
#  'I propose',
#  'Or tmr',
#  'We may watch the demon slayer movie later',
#  'We still snappin hold on',
#  'LMAOOO',
#  'Ohhhh',
#  'Results?',
#  'WHAT THE FUU-BOOOOOMMMMMMM',
#  'Fuck u Matt',
#  'John when the sashimi hits the table',
#  'My b',
#  'John ordering his 50th piece of sashimi',
#  "It's u_u girl",
#  '😂😂',
#  'Ya boy’s been a dirty slut can’t lie',
#  'I only told u guys bc its an uwu girl',
#  'WHOOOOOAA',
#  'How about you Rev me up like Pochita and then I can be the devil inside you ( ͡👁️\u202f͜ʖ ͡👁️)',
#  'I will give you $50',
#  'mattee bro send her the google doc',
#  'Hello 0_0 my watchlist is chainsaw man 1_1 and vinland saga >_< how bout u OwO',
#  '@_@',
#  'u_u',
#  'Got his priorities in line',
#  'I’m kinda flattered mattee is finally gonna get some and his first reaction was “I can’t wait to tell the boys”',
#  '@FoundingChad punching the air rn',
#  'Yk what im sayin',
#  'Bouta cop one reaaalllll quick',
#  'Did this bitch just say u_u',
#  'Me seeing a debate in the master chat',
#  'RIP',
#  'You’re a dead man hagrid!',
#  'RIP',
#  'Ye',
#  'Ah i c',
#  'Monke place shield that stops explody bitch from exploding bitch 2',
#  'What am I looking at here',
#  'Then you didn’t do it',
#  'I’ve done this but forgot to clip it',
#  'Was he short skinny with a high pitched voice',
#  'It might’ve been',
#  'Was this that heat transfer professor I went to that one time when I was there?',
#  'O i c',
#  'There was a 4 month gap they could have easily found something',
#  'Im surprised they took him out without any investigation',
#  'But there isnt any actual evidence of a relationship',
#  'Wow',
#  'Head of the department',
#  'A professors response',
#  'Original reddit post',
#  'Send the actual link',
#  'Yoooo professor at UB might have been fucking a student and has been removed from teaching',
#  'Nice',
#  'I can’t be racist I use dark mode',
#  'The knowledge of a true racist',
#  '5K or cross country',
#  'What race would u make him',
#  'Ah yes the Jamaican grim reaper',
#  'Wtf is warner bros doing',
#  'End of an Era lads',
#  'no',
#  'Yo fifa tn boys',
#  'YOU FUCKING IDIOT',
#  'Look i said that here',
#  'Yeah im off tmr',
#  'Lmaooo',
#  'https://t.me/c/1179447288/87623',
#  'Yessir',
#  'I woke up, everything went downhill after',
#  'Off tomorrow?',
#  "Today's my last day of the week :)",
#  'Someone woke up on the wrong side of the bed this morning',
#  'What’s so good about it',
#  'Is it',
#  'Gm',
#  'Good morning',
#  'And apple mid',
#  'Well I wanted to read',
#  'https://twitter.com/Forbes/status/1580299530205302784',
#  'Dude thinks I typed this up like some Fibbage prompt lmao',
#  "I was expecting more good music from him, shame he's so far gone",
#  'Woah, contradicting respects going on here...',
#  'Send the actual link',
#  'Thanks omrahn',
#  '“The same jutsu won’t work on me twice”',
#  '“ i too”',
#  'He did say',
#  'I mean not really',
#  'Very ironic',
#  'New meta dropped',
#  'Based',
#  'I too love trivializing and mocking peoples complaints',
#  'Oh god a screenshot everyone run for cover',
#  'Bitch',
#  'u tried to throw me under the bus',
#  "So to wrap this conversation up,\nI don't deserve to be respected and this is a non issue and I hate no right to be upset.\ngot it 👍",
#  'Solution:',
#  'A solution looking for a problem',
#  'Respect must be earned',
#  "What's the solution, Idk",
#  'Das crazy dawg',
#  "Everyone needs to respect each other but each other's respects start contradicting",
#  'lots of great points',
#  'Interesting',
#  'Fair? You want… fairness?',
#  'Hacking to the gate 😂',
#  "Can't wait to fwd this haha",
#  'We all do this tbf',
#  'JOHN STOP BRINGING REAL LIFE INTO THIS YOU ALWAYS DO THISIHATEYOUFUCKINGRETARD',
#  "Honestly everyone should just give me a # from one to 10 and that's how much respect I'll show them",
#  'U wish u were a line fatty',
#  'He’s not outta line he’s perfectly in line',
#  'Respectfully of course',
#  'Fuck you',
#  'I respect your paradoxical boundary',
#  'I too will advocate for excessive amounts of group chats and also ban everyone from adding me to groupchats',
#  'Will anyone respect that boundary? Of course not',
#  'One of which is I dislike too many groupchats',
#  'I also have boundaries',
#  'You love gargling balls so much im surprised your even able to produce sperm properly after witnessing the greatness of kanye',
#  'Bro jamshid is gonna be making more than all of us combined when it’s all said and done',
#  'Im saying',
#  'What the hell are you saying',
#  'Why not throw a little cte in there',
#  'U always sucking off jamshid for his money',
#  'Yes',
#  'You really want Kanye in your corner?',
#  'Mr west has 😎',
#  'Brockport? Neva heard of it 😎',
#  'mid input',
#  'You guys are all dumb',
#  'As a third party',
#  'This is a majority conservative group chat',
#  'Free dumbs',
#  "It's simple",
#  'Discourse',
#  'I’m just asking u guys not to do it idk why you’re so against it',
#  'Then why even send it? 🤔',
#  'Yeah we know',
#  'I too dont like admitting when im wrong',
#  'AHHHHH JALIL MIGHT PLAY OVERWATCH GOTEM FRAUD CRINGE OWNED',
#  'This wasn’t shit like that',
#  'He did leave the groupchat because of shit like that',
#  'I mean',
#  "Apparently sending a screenshot of a harmless yes/no question is bad. Y'all so dramatic",
#  'This is the store',
#  'Lie',
#  'He don’t got pork',
#  'He’s Muslim even the bacon is beef',
#  'But HE PUTS BACON ON THE GRILL',
#  "I honestly think he's gonna do that",
#  'Just no pork',
#  'IM down',
#  'Honestly I’m down to go with whoever wants to go',
#  'NOW WE PUT THE MOZZARELLA STICKS IN THE SALAD',
#  'We ask for a salad',
#  'We don’t get a bev',
#  'yo Ock lemme get a chop cheese mcdgriddle the ocky way',
#  'I think that’s been done tbh',
#  'Hey ock can I get a ramen and pop tart burger but NO SPINACH',
#  'We gotta get something original at the ocky store',
#  "I've been asking for MONTHS and now u wanna go",
#  'Are u fucking kidding me',
#  "Bruh, I stopped a while ago, don't bring me into this cuz u fucked up 🥰",
#  'How about you guys stop cause I asked, please',
#  'This wasn’t even a gotcha or an insult in any way lol',
#  'If u go through the media in the gc 90% of text screenshots are john',
#  'i love being a dick about peoples boundaries',
#  'i agree with you',
#  'no no',
#  'Ah yes exaggerate',
#  'I too love dictating what people deserve to be upset about',
#  'kinda yeah',
#  'is that a serious offer',
#  'You wanna go?',
#  'Omrahn',
#  'It’s so people who get banned for cheating can’t make a new account that easily',
#  'What a trivial thing to be upset about',
#  "I'm just saying, I haven't done it in forever",
#  "it's fucking annoying and i've said before i don't like when you guys do it",
#  "Y'all?!",
#  'Wooooooooooow',
#  'Y’all take screenshots of my messages left and fucking right',
#  'I do hate it',
#  "If this guys still in the game, I'm down",
#  'My overwatch experience',
#  '👍',
#  'I LOVE GETTING TO WORK WHILE THE FUCKING SUN ISNT UP',
#  'I FUCKING LOVE WAKING UP EARLY',
#  '“Brendan should have kept running” - jamshid',
#  'Oh thats where that meme came from',
#  'Give this man a tv show honestly',
#  '2nd half time',
#  'Only childs dont count',
#  '?',
#  'Eldest child gang',
#  'yeah talk yo shit',
#  'Everyone complains about dead groupchat and no activities until its time to actually commit to something smdh',
#  'but i take the wok to poland',
#  'mattee you might be that guy',
#  'Fr fr lmao on moms thats brazy',
#  'Goddamn that’s funny',
#  'greg demoted to defense if he does',
#  'Is Matt making an appearance?',
#  'I’ll be on at 830 tonight',
#  'No its cuz spongebob took the vax',
#  'Wasn’t the cure for this just taking a shower or something',
#  'Hope u feel better ♥',
#  'Sick of you bitches',
#  'What kinda sick',
#  'I blame the sarwaris',
#  'And 2nd week, already no event',
#  'We picked one day',
#  'Look at that',
#  'Oh wow hassib',
#  'Smh no fifa on a Tuesday',
#  'Is it dead or poppin',
#  'Another dead chat',
#  'Add me plz',
#  'Something something terrorist',
#  'Its poppin rn',
#  'Add me back',
#  'Oh shit',
#  'I will drive to Long Island and blow up your house',
#  'Please use the fifa chat ty',
#  'I see no reason why not',
#  'Well if Jalil and jamshid are back',
#  'I hope we have fifa',
#  'So is fifa happening tn?',
#  'Do you even limewire',
#  'Yes',
#  'U guys remember dial up?',
#  'Just watched the mario movie its pretty good',
#  'M’Award',
#  'Jesus christ',
#  'Unions municipalities local governments whatever',
#  '"Unions"',
#  'Is fifa Tuesday still a thing tomorrow?',
#  '"dealing with crap" = prophet',
#  'Tomorrows lottery numbers are 420 69 69',
#  'I must be a prophet',
#  'No I mean like even if you get the funding you’d have a nightmare dealing with unions and crap',
#  'We are truly our own worst enemy',
#  'Oof',
#  'Tik tok go crazy td',
#  'Date?',
#  'So did I \U0001f972',
#  'I thought ur going to a bills game in NYC what the FUCK',
#  'I can maybe do end of November',
#  'I’m going to be in Michigan so no',
#  'So I can plan my life',
#  "@biggiethumbs Brendan Greg Stimitz plz tell me that we're hanging out Nov 4th weekend",
#  'I need to know something now',
#  'Damn',
#  'They’ll reappear on Tuesday',
#  'Still can’t believe jamshid thought he was top 4',
#  'Goated anime',
#  'Ah a man of culture leaving that crap',
#  'Damn, add me back to the FIFA chat!',
#  '45? Im in 63. Ur missing out',
#  'Now this I can get behind',
#  'Matt should play fifa 23 instead of watching the notebook',
#  'Mid',
#  'We should just do this to Russia',
#  'We should stop supporting them and start worrying about ourselves',
#  'He he he',
#  'They’re lowkey giving Russia the works',
#  'They still goin?',
#  "Life ain't so bad",
#  'Ukraine should surrender',
#  'Quick someone say something controversial',
#  'Damn we have 45 group chats and they’re all dead',
#  'I am free tomorrow night believe it or not',
#  'Apple users on suicide watch',
#  'House of the dragon would never',
#  'Ep7 came out today',
#  'Wow',
#  'is it really that bad',
#  "why i can't",
#  'give me one good reason',
#  'We gotta say it somewhere',
#  'We can’t use words like faggot in that chat',
#  '😈😈😈',
#  'Why’d u stop typing',
#  '😈😈😈😈',
#  'Took a while jammy',
#  'I doubt you will surpass me',
#  'Jamshid count your days',
#  'New pr 245x3',
#  'Greg had to explain it to me lmao',
#  'LMFAO',
#  'cringe',
#  'Thanks zaddy',
#  'People seeing me walk in with bobby bitch blasting on repeat',
#  'WOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO',
#  'I’m on my couch actually',
#  'Lol',
#  'I see the cum wall u got',
#  'I see the sandwich on your chest',
#  'I see u on your bed',
#  'Yeah u',
#  'You look like u need some bitches',
#  'You almost look like your balls dropped',
#  'That mustache is so cute',
#  'I quite literally know more than u',
#  'I thought you had weights to lift',
#  'WOOOOOO',
#  'IM IN JIM',
#  'Check mate',
#  'Fifa gc and mechanical gc cant be the same',
#  '…',
#  'If i had more energy I would’ve continued this convo then argued',
#  'The main chat and the FIFA chat cant be the same thing',
#  'Im back',
#  'Yea.. That makes it So unsettling 😂',
#  'The loop makes it look like she’s jerking off',
#  'This is so unsettling',
#  'Go watch this movie, ty',
#  'Bye',
#  'I go pump iron',
#  'Jalil and jamshid both left telegram but we have to make new gcs because they spoiled asses think everything is about them and then will throw a fit when the topic is not there pleasing',
#  'There’s literally a skip messages button',
#  'How bout you shut the fuck up and let people talk',
#  'The main chat and the FIFA chat cant be the same thing',
#  'Its true tho',
#  'All that typing',
#  '🥰',
#  'This shit again',
#  'But yeah I don’t care enough to count messages',
#  'The way telegram exports makes it harder',
#  'Then again by color',
#  'Cause I was going to see if I could filter by messages sent by deleted account',
#  'For deleted accounts?',
#  'How do you need python to count x number of messages',
#  'Use Matlab',
#  'Cringe',
#  'I have all of them though',
#  'Won’t work unless I can learn python',
#  'Your conclusions?',
#  'No I was trying to count messages',
#  '^',
#  'What timeline',
#  '@biggiethumbs did u ever finish that timeline btw?',
#  'You called any episode of code geass with character building a filler',
#  'Yeah I love hearing someone rambling without moving their mouth',
#  'Monologues are the best',
#  'If I hear so much as one monologue I’m quitting',
#  'Hassib not allowed to watch',
#  'Wtf',
#  'I win bye bye',
#  'Cope',
#  'Ratio',
#  'L',
#  'Exposed',
#  'Nope',
#  'Anime just fucking sucks in general',
#  'I am intrigued',
#  'Manga is supposedly very hype',
#  '@FoundingChad',
#  'Idk how to @ a name',
#  'Android idiots smh',
#  'Is nothing sacred smh',
#  'fuck u John',
#  'From this chat',
#  'He fwded omrahn message!',
#  'What did John do now',
#  'Low blow john',
#  'Screw u John',
#  'Ofc the people who hate popular movies hate the Mario movie',
#  'An hour left of work and I’ve mentally checked out 3 hours ago',
#  'Comes out next week',
#  'Is this show good? I see it everywhere',
#  'Greg wow',
#  'Brendan there’s no thumbnail I’m not clicking that',
#  'This guy is shit',
#  'Some heat^',
#  'https://youtu.be/hFZFjoX2cGg',
#  'Great channel',
#  'Oh I’ve been watching fam',
#  'If you guys wanted that engineering guy i like to watch',
#  'https://www.youtube.com/c/PracticalEngineeringChannel',
#  'Got em',
#  "There's noticeable actors that we could've memed on too",
#  'Fuck you guys for not watching it last weekend',
#  'Great movie',
#  'I watched Smile',
#  'Maybe here',
#  'O',
#  'or at least rejoin',
#  'This is wrong',
#  'Oh i thought u meant came back',
#  'Are we making a fucking timeline?',
#  'Nah',
#  'This will never be addressed but it should!',
#  'June 11th',
#  "it's actually fun trying to figure this out",
#  'reasons',
#  'Wha',
#  'thank',
#  "You're welcome",
#  'June 11th',
#  'or at least rejoin',
#  'is important',
#  'halp',
#  '@everyone what date did jalil and jamshid delete telegram',
#  'What GC should we make now?',
#  'Yo Jamshid',
#  'Get some help',
#  'Stop it',
#  'wHaT Gc SHoUlD i MaKe nOw',
#  'Like u da be sittin in your corner thinking about',
#  'Im sorry your brain is so fried by medical knowledge the best your shower thoughts can be are fucking gc ideas',
#  'get his ass boi',
#  'Its the main chat',
#  'Mattee why even stay in this chat',
#  'This man doesn’t watch wild n out and it shows',
#  'Dirty ass nibba',
#  'You took a shower and lost weight',
#  'U look like future’s past',
#  'Alright future chill',
#  'U shlob on dis knob',
#  'Yo mama',
#  'Okay fine I’ll call him later',
#  'In what world',
#  'Plz Take this to the "eldest childs who\'s the bigger virgin battle" GC plz tyvm!',
#  'The delusion',
#  'Still can’t believe jamshid thought he was top 4',
#  'Jalil and Mattee would be swapped in an undeleted world obviously',
#  "If only omrahn wasn't at the airport",
#  'If only fifa was as successful at fortnite',
#  'The shot was deflected by an enemy player and rolled into the goal',
#  'I believe I scored the 2nd goal',
#  'It was the game we lost 2-5',
#  'Damn i gotta get back into the habit of sending clips',
#  'Which goal',
#  "I'd like to see it plz",
#  'I hope @biggiethumbs clipped that one :/',
#  'Oh 😂',
#  'You gotta leave a few seconds for the “OOOOO”',
#  "I'm not sure what u mean",
#  '?',
#  'John',
#  'fraud',
#  'Fake news',
#  "could've played fifa",
#  'You read the important part at least',
#  'Opens telegram',
#  'Wow 300 + messages!\nFifa must be going well!\nI can’t wait to read whats going on',
#  'Wow look at all those messages I skipped at the click of a button',
#  "It's not even close",
#  'Who uses exclamation points the most?',
#  'The better question is who reacts the most to messages',
#  "excuse me this isn't fifa related",
#  'Most messages:\nJohn\nHassib\nBrendan\nMattee\nJalil \nJamshid\nOmrahn',
#  'Mattee I need you',
#  'Chess?',
#  'Brendan',
#  'Appearing offline',
#  'Notorious for random “I need you to do this”',
#  'He was dropping my dad off',
#  "You couldn't have dropped him/her/it off 3 hours earlier Omrahn",
#  'My dude join the party',
#  "I'm on but Where's everyone else lmao",
#  'I never planned on 8',
#  'Jalil 🍎 finish yo chicken',
#  'I was editing my character',
#  'John where tf are you',
#  'No way are Greg and bren on by 8',
#  'John Brendan Jalil 🍎',
#  'We start at 8:10',
#  'Is Matt making an appearance?',
#  'John @biggiethumbs Omrahn Jalil Brendan Gregory',
#  'T minus 25 minutes',
#  'Who asked',
#  'I had a good August',
#  'Rest are trash',
#  'One good day',
#  'August is highkey mid',
#  '8 it is',
#  '8 is fine too',
#  'Works for me',
#  'No way am I on till 11',
#  'I’d rather 8-11',
#  'Yea',
#  'What say the white people',
#  'Works for me',
#  'How about 830 sharp for all',
#  '8 for us, 7:30 for greg and Brendan',
#  'No way are Greg and bren on by 8',
#  '8-11',
#  'Make a miss chat chat',
#  'I miss the fifa announcement chat',
#  'This man spitting facts',
#  'Hope everyone is having a nice day and excited for FIFA tn!',
#  'Na',
#  "It shouldn't be this hard :)",
#  'We never figured scheduling out huh',
#  'Today, 1 year ago',
#  'Due to scheduling issues the only day for squid games is tonight',
#  'You guys know what today is 👀',
#  'This has already been done',
#  'Is this your business plan',
#  'Overwatch 2 anyone??',
#  'Yo ima build a school',
#  'But as a old person',
#  'And we strengthen those mobile areas early on to live healthy not just as an athlete',
#  'When they’re mobile and shit',
#  'But start them off at a young ageb',
#  'Maybe lighten the load',
#  'This is what we need',
#  'I dont get it',
#  'Thought that was a dude',
#  'What is bitchs?',
#  'I dont get it',
#  'You looked at it so analytically instead of just using common sense',
#  'What do you think',
#  'You’re kidding right?',
#  'It’s also a wireless charger',
#  'Having Simpsons decorations in front if the ps5 is also weird',
#  'Agreed',
#  'Having an alarm clock underneath seems strange',
#  'Mid setup mid player',
#  'This is a beautiful video, the bois spending the last mins of the OW1 servers together',
#  'This gif is so perfect for how I feel at the end',
#  'Yeah I should be free',
#  'Tomorrow? Fifa tomorrow? On fifa Tuesday?',
#  "Who's free for fifa tmrw?",
#  'This shot is SICKKK',
#  'Mid',
#  'Is the nfl vr game on ps vr Jalil ?',
#  'Dbz amc’s were peak YouTube back in the day',
#  'Still cool',
#  "Nvm it's an amv",
#  'THEY REANIMATED NARUTO VS SASUKES FIRST FIGHT',
#  'He just looks like a normal guy',
#  'The roasting is insane',
#  '#leaveDreamalone',
#  '...mid',
#  'Poor guy',
#  'So... How about Dreams face ey?',
#  'So you’re the reason John is horny for anime uwu girls?',
#  'Everything is mid, never be excited for anything, only negativity!',
#  'I was excited for one thing',
#  "Rue relapsing returns but now she's in college and has no safeguards",
#  "It's gonna be terrible",
#  "The fact this isn't us rn is incredibly dissapointing",
#  'Make up is so powerful',
#  'John, just subscribe to her OF and call it a day',
#  'Jesus needs me',
#  'John you need Jesus',
#  'Jamshid mid',
#  'YES BRENDAN BE SALTY',
#  'Ur dick prob limp from that twitch girl',
#  'Jesus Christ get off my dick already',
#  'Jamshid swimming in that copium',
#  'Sorry u cant figure it out with an android',
#  'He actually looked it up lol',
#  'Her twitch is NotAestheticallyHannah you fucking faggot',
#  '^there it is',
#  'please send this to the "john\'s being a dick" gc tvym!',
#  'U faggot',
#  'She is uwu girl',
#  'Got it',
#  'Welp, now its clear ur just being a dick for whatever reason you have',
#  'Like use ur Apple Search App?',
#  'Maybe u can search?',
#  'Bro',
#  'John',
#  "Don't delete my shit",
#  'Cringe',
#  'Anyways, what’s that chicks name',
#  'Who knew making Omrahn admin was a mistake',
#  'All hail Greg Stimitz',
#  'Thank fucking God for this chat',
#  'Jam complains about messages then stares at his phone constantly',
#  'Yes',
#  'Man couldn’t scroll past 1 message without getting his panties in a twist',
#  'Please take this convo to "is there a GC for this?" GC Plz thank u',
#  'Aren’t u driving',
#  'Man shut YO BITCH ASS UP',
#  'He is a rapper',
#  'Theres a rap gc',
#  'There is 100% a music gc',
#  'thank GOD',
#  "his latest album sold 17k, it's over",
#  'If will smiths movie wasn’t enough to convince nothing will',
#  'Until more and more parents realize how stupid it is to let their kids play',
#  'Everybody always says nfl is done but nfl will remain top dog',
#  'LMAOOOOOOOO',
#  'John',
#  'Nfl > nba',
#  'Lol NBA > NFL is a hot ass take',
#  'John',
#  "It's hard to focus without pics",
#  'U missed it',
#  'You can only say this is your present mf',
#  'Where u at its 2 smh',
#  'Wrong chat',
#  'We can grill though',
#  'I mean.... It did rain already and is gonna rain again today',
#  'Wow',
#  'Wut',
#  'U 1v1',
#  'But to take pieces',
#  'Its chess',
#  'Its moving away',
#  'Maybe Hassib was right',
#  'Did it rain 🤔',
#  'Im ducking bored and awake',
#  'Idea: tier lists for group chats',
#  'Fps chess',
#  "My butthole is stuffed, I'm ready",
#  'This game is a fucking shit show',
#  'You are now invited to the Pokemon chat',
#  "That's actually insane",
#  'Nsfl',
#  'Click at your own risk',
#  'This is our FIFA chat now',
#  'Hassib had to have beeen high',
#  'God damn',
#  'So far away',
#  'We appreciate u making it for sushi friday',
#  'Concert != traveling',
#  'You went to a concert yesterday…',
#  "In retrospect, this is crazy to say considering I was in Korea a week ago and now I'm on LI",
#  'Love ur self',
#  'You think that’s grotesque',
#  'My sweet summer child',
#  'Plz do',
#  'Shall i share',
#  'I have something absolutely grotesque',
#  'A little more sus don’t you think?',
#  'John you’re thinking about that too much',
#  'Matt this dude sus',
#  'He’d be on time every time',
#  'The only solution is for one of us to suck johns dick',
#  'Me neither',
#  "I got one topic of roast for each of ya'll",
#  'We could',
#  'Maybe we should play jackbox tn since the roasting is on point',
#  'Lmfao',
#  'Wrong chat',
#  'Jamshid all the time',
#  'John for his once a year trip for the boys',
#  'John for his third concert in a week',
#  'Ngl it doesn’t even feel real',
#  "That's some dedication",
#  'Reddit carefully showing me the same shit over and over again',
#  'No',
#  'So john unifies separate substances as a catalyst to create a reaction',
#  'Catalysts technically unite other chemicals to create a reaction',
#  'https://t.me/c/1179447288/84366',
#  'Most of the time yes',
#  'I truly am the great uniter',
#  'They tend to agree on most things recently',
#  'You know how fucked up you have to be to make me jalil and jamshid agree on something',
#  'Objectively not funny',
#  'Try harder',
#  'Classic gif',
#  'Simple\nSearch "wam"',
#  'That poor kid lol',
#  'Howd u find that',
#  'Whats the 🤔 wecommended 😭 wamount of 😜 ded-da-dated wam 😂 i shud halv 🧐 on my servur 😳',
#  'Can I pway on the ps5 UwU',
#  '*electric skateboards',
#  'Inability to pass the ball',
#  'Inability to ride hoverboards',
#  'It was the wrong answer',
#  'Strabismus?',
#  'He can watch two fifa screens at once',
#  'It’s a feature not a bug',
#  'Lmao',
#  "What's wrong with them",
#  'and how does it feel to be wrong when it wasnt even your question',
#  'I said him',
#  'Strabismus',
#  'Yesssir',
#  'Only if he can name the defect',
#  'Brendan make fun of Jamshid’s eyes',
#  '^',
#  'Bro how have you never noticed',
#  'Show me plz',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '❓ Help',
#  '☕️',
#  'No',
#  'Change my mind ☕️',
#  'You’re a genetic defect',
#  'I CAN SAY FIRST HAND MILITARY MONEY IS OBSCENE',
#  'DIVERT MILITARY FUNDS TO PAY FOR PUBLIC HEALTH CARE',
#  'Its a genetic defect',
#  'POLITICAL ARGUMENT HERE WE GO',
#  'I mean nuanced when compared to beliefs generally ascribed to either party',
#  'Everyone is dumb and bad at video games except jamshid',
#  'Brendan the most nuanced thign about you is your foot stance',
#  'The only nuanced opinions are jamshids',
#  'You do not have nuanced opinions',
#  'https://t.me/c/1179447288/79499',
#  'That sounds like socialism with extra steps',
#  'DEMOCRATIC socialism',
#  'This sounds so unrepublican',
#  'SO EVERYBODY JUST FOLLOW ME',
#  'NOW THIS LOOK LIKE A JOB FOR ME',
#  'Docs shouldnt get paid less, everyone else should be paid more',
#  'The goat',
#  'It was slim shady',
#  'Right right he had gloves on',
#  'He does not deserve to have a Porsche for that',
#  'I could’ve done that',
#  'Ik but it was a funny typo',
#  'My dude I went to a dermatologist and all he did was pop a cyst on my head with a needle',
#  'The proper line is "I got 99 problems and they all bitches" - Kid Cudi SMH',
#  'You had a point',
#  'No no',
#  '*paid',
#  'Doctors need to get laid extra so they can make up all the income they lost from studying till they 35',
#  'I have no idea I don’t research my hot takes',
#  'Doctors get fucked',
#  'I vaguely remember writing an essay on doctors and athletes',
#  '"Give up on your dream. Send those nfl players straight to hell"',
#  'Aren’t they underpaid',
#  'Doctors',
#  'You know who else is overpaid?',
#  'You know all this talk of athletes being overpaid',
#  'Here’s your big bag of money',
#  'Just walk it off pal, you have 36 more hits for this game',
#  'Dudes ripping a mad guitar solo, all clear',
#  'lmao',
#  'Fuck u uys',
#  '“Quick check his fingers”',
#  'Its on purpose',
#  'Ik',
#  'Mf you still haven’t told us your plan 😂😂',
#  'Actually sounds cool asf',
#  'Interesting',
#  'You don’t know how vague this is 😈',
#  'Neuroscience concussion inspector for NFL',
#  'HiS BuSinEsS pLAn',
#  '😂😂😂',
#  'Sends gif*',
#  'I just want to see what u guys think',
#  'What do u think im going to do after graduation',
#  'Oof',
#  'THE RECKONING WILL BE SWEET',
#  'I can’t till mattee graduates and doesn’t make anywhere near what we do lol',
#  'Thanks man',
#  'SHE ALL 99 OF THEM',
#  'I GOT 99 PROBLEMS AND A BITCH AINT ONE',
#  'We let the little boy dream',
#  'We know Omrahn, we know',
#  'I hope Jamshid becomes a professional youtube boxer like Dr. Mike one day',
#  'Mattee will never understand, he’ll never be one',
#  'Doctors like to keep things organized',
#  'OOF',
#  'Cuz unlike someone, i dont have a life',
#  'Well yes',
#  'Jamshid after wasting his life on a degree just to get mad at group chats',
#  'I jk but dont say anything',
#  'Cope',
#  'This man is a fraud',
#  'Yes',
#  'After i turn u 😈',
#  '🤔',
#  'U gone want some dick',
#  'Gotta question my choices?',
#  'THIS MANS IN CLASS LMAOOOO',
#  'Wasted college on books?',
#  'Why u on my dick bro',
#  'This man texting 8 guys at once',
#  'In class',
#  'You should be with your girls then',
#  ':)',
#  'Built different',
#  'U get mad books',
#  'I get mad girls',
#  'Yee',
#  'Shouldn’t you be going to college parties or something?',
#  'If u cant make that connection then maybe its time u put the booms down and go outside dr :)',
#  'Even if we sent studies jamshid wouldn’t read them',
#  'So',
#  'I cant add u to chats',
#  'Jamshid',
#  'Maybe it would be if you kept nfl stuff in there',
#  'How would you know? Wheres your PhD? Exam scores? Publications?',
#  'The nfl chat is not even that active',
#  ':)',
#  'Please leave your insecurities',
#  'Who are you?',
#  'Im talking to them',
#  'Brendan and hassib are responding',
#  '🥱',
#  'then stop fucking texting it in here',
#  'If he doesnt want to participate in it',
#  'There is literally an NFL chat',
#  'Please... get a hotel',
#  'Shit is fucked',
#  ...]

# %%
messages_new = messages[messages['text'] != '']

# %%
corpus = messages_new['text']
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(corpus)
X_train
# Out:
# <963x3411 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12097 stored elements in Compressed Sparse Row format>

# %%
len(vectorizer.get_feature_names())
# Out:
# 3411

# %%
topic_model = NMF(n_components = 5)
topic_model.fit(X_train)
# Out:
# NMF(n_components=5)

# %%
# to get H
H = topic_model.transform(X_train) # transform document into topic vector representation

# to get W 
W = topic_model.components_ # word component weights for each topic

print("Shape of W is " + str(W.shape))
print("Shape of H is " + str(H.shape))
print("Shape of X_train is " + str(X_train.shape))
# Out:
# Shape of W is (5, 3411)
# Shape of H is (963, 5)
# Shape of X_train is (963, 3411)

# %%
W[4]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.00100232, 0.00128999,
#        0.00128999])

# %%
for index,topic in enumerate(W):
    print(f'THE TOP 10 WORDS FOR TOPIC #{index}')
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-25:]])
    print('\n')
# Out:
# THE TOP 10 WORDS FOR TOPIC #0
# ['even', 'take', 'feel', 'also', 'back', 'end', 'something', 'marvel', 'cause', 'good', 'come', 'see', 'day', 'people', 'know', 'think', 'time', 'thing', 'say', 'movie', 'guy', 'show', 'get', 'go', 'watch']
#
#
# THE TOP 10 WORDS FOR TOPIC #1
# ['chat', 'guess', 'correct', 'write', 'private', 'fb', 'information', 'share', 'wisdom', 'nobody', 'time', 'channel', 'game', 'ranking', 'question', 'greg', 'omrahn', 'jalil', 'enjoy', 'winner', 'bot', 'please', 'rate', 'point', 'answer']
#
#
# THE TOP 10 WORDS FOR TOPIC #2
# ['do', 'gc', 'hometown', 'ape', 'talk', 'sense', 'slow', 'separate', 'discuss', 'telegram', 'john', 'time', 'everyone', 'new', 'team', 'however', 'nfl', 'concede', 'part', 'argue', 'want', 'chat', 'pokémon', 'group', 'make']
#
#
# THE TOP 10 WORDS FOR TOPIC #3
# ['together', 'dick', 'get', 'battlefield', 'suck', 'think', 'good', 'fun', 'cause', 'skill', 'start', 'team', 'night', 'session', 'bad', 'win', 'guy', 'video', 'div', 'lose', 'jamshid', 'last', 'fifa', 'play', 'game']
#
#
# THE TOP 10 WORDS FOR TOPIC #4
# ['fifa', 'little', 'division', 'defense', 'give', 'need', 'nothing', 'offense', 'let', 'piece', 'score', 'stupid', 'pass', 'goal', 'ball', 'omrahn', 'jalil', 'greg', 'shit', 'john', 'brendan', 'hassib', 'jamshid', 'mattee', 'fuck']

# %%
# %%capture topic_word_plot
def plot_top_words(W, feature_names, n_top_words, title):
    fig, axes = plt.subplots(1, 5, figsize=(15, 8), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(W):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 20})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=15)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=25)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

n_top_words = 20
tfidf_feature_names = vectorizer.get_feature_names()
plot_top_words(W, tfidf_feature_names, n_top_words, "Topics in NMF model")

# %%
topic_word_plot()

# %%
valid_messages = messages_new.index.unique()
len(valid_messages)
# Out:
# 963

# %%
topic_name_dict = {0: 'Entertainment', 1: 'quizzarium', 
                   2: 'make_group_chat', 3: 'games', 
                   4: 'arguments'}

# %%
# takes in list of documents and plots topic weight vectors for each document
def tweet_topbreakdown(locator):

    print(messagess.loc[locator].text)
    int_index = messages_new.index.get_loc(locator)

    topic_keys = topic_name_dict.values()
    zipped_tuple = list(zip(topic_keys, list(H[int_index,:])))

    topic_breakdown = pd.DataFrame(zipped_tuple, columns = ['Topic', 'Weight']).set_index(['Topic'])
    topic_breakdown['Normalized weight'] = topic_breakdown['Weight']/topic_breakdown['Weight'].sum()

    sns.barplot(y = topic_breakdown.index, x = 'Normalized weight', data = topic_breakdown)
    plt.title("Distribution of topics for message no. " + str(locator))
    plt.show()

    return topic_breakdown

# %%
tweet_loc_list = [valid_messages[100],valid_messages[99],
                  valid_messages[390],valid_messages[750],valid_messages[900]]
#900 is hilarious
g = list(map(tweet_topbreakdown, tweet_loc_list))
# Out:
# Yeah brendan was right I tried finding an actual study about the effects of debt forgiveness on inflation but couldn’t
# Damn mattee must be getting bullied hard in college if he’s too scared now to make fun of hassib
# Jamshid I said the only reason you’re at the top of the leaderboards is cause you force the offense to play around you
# I can abandon post and play defense while I live all the live long day but that up there? That’s the endgame
# (Div 1)
# Hassib scored, Hassib fucked up, Brendan fucked uo, John fucked up, Omrahn fucked up,

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(random_state=42, learning_rate=100)
tsne_trans = tsne.fit_transform(H)
tsne_trans = pd.DataFrame(tsne_trans, columns = ['TSNE1', 'TSNE2'])
# Out:
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:349: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:350: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:349: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# /Users/jalilsarwari/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:350: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max

# %%
# for each document takes the topic with highest weight and assigns document to this class -- hard clustering.
tsne_trans['class'] = np.argmax(H, axis = 1)
tsne_trans['class'] = tsne_trans['class'].replace(topic_name_dict)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x = 'TSNE1', y = 'TSNE2', hue = 'class', data = tsne_trans, palette = 'tab10')
plt.title('Visualization of COVID-19 tweet topic segmentation')
plt.show()
